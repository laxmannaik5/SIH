# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
l_img = cv2.imread('image2.png')

# %%
img = l_img[470:,300:,:]

# %%
plt.imshow(img, cmap='gray')

# %%
kernel1 = np.ones( (3,3), dtype=np.uint8 )

# %%
erode_img1 = cv2.erode(img,kernel1)

# %%
# cv2.imshow('1',img)
# cv2.imshow('2',erode_img)
# cv2.waitKey()
# cv2.destroyAllWindows()

# %%
#kernel2 = np.ones( (1,3), dtype=np.uint8 )

# %%
dil_img1 = cv2.dilate(erode_img1,kernel1)

# %%
cv2.imshow('1',img)

cv2.imshow('2',erode_img1)

cv2.imshow('3',dil_img1)
cv2.imwrite('img2.png', dil_img1)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
 erode_img2 = cv2.erode(dil_img1, kernel1)

# %%
dil_img2 = cv2.dilate(erode_img2,kernel1)

# %%
cv2.imshow('1',img)
cv2.imshow('2',erode_img2)
cv2.imshow('3',dil_img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = cv2.imread('img1', 0)
_, blackAndWhite = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)

nlabels, labels, stats, centroids = cv2.connectedComponentsWithStats(blackAndWhite, None, None, None, 8, cv2.CV_32S)
sizes = stats[1:, -1] #get CC_STAT_AREA component
img2 = np.zeros((labels.shape), np.uint8)

for i in range(0, nlabels - 1):
    if sizes[i] >= 50:   #filter small dotted regions
        img2[labels == i + 1] = 255

res = cv2.bitwise_not(img2)

cv2.imwrite('res.png', res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-5e069604468b> in <module>
#       7 nlabels, labels, stats, centroids = cv2.connectedComponentsWithStats(blackAndWhite, None, None, None, 8, cv2.CV_32S)
#       8 sizes = stats[1:, -1] #get CC_STAT_AREA component
# ----> 9 img2 = np.zeros((labels.shape), np.uint8)
#      10
#      11 for i in range(0, nlabels - 1):
#
# AttributeError: 'NoneType' object has no attribute 'shape'
